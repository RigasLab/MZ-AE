# %%
import torch, pickle, os
from torch.utils.data import Dataset, DataLoader
from src.PreProc_Data.DataProc import StackedSequenceDataset
import numpy as np
from src.Eval_MZA import Eval_MZA
import matplotlib.pyplot as plt
import pandas as pd

# %%
torch.cuda.empty_cache()
exp_dir   = "Trained_Models/Cluster_Models/Exp2.2.1_2DCyl_Num_seqlentest_ts2"  #Experiment Directory
# exp_name  = "sl32_nhu40_numobs8_bs16_lr5e-5"                #One of the experiment names

models = []
for exp_name in os.listdir(exp_dir):
    if exp_name != "results" and exp_name != ".DS_Store":
        print(exp_name)
        models.append(Eval_MZA(exp_dir, exp_name))
models
# eval_mza = Eval_MZA(exp_dir, exp_name)
# Out:
# sl16_nhu40_numobs8_bs16_lr5e-5
# sl4_nhu40_numobs8_bs16_lr5e-5
# sl48_nhu40_numobs8_bs16_lr5e-5
# sl10_nhu40_numobs8_bs16_lr5e-5
# sl8_nhu40_numobs8_bs16_lr5e-5
# sl2_nhu40_numobs8_bs16_lr5e-5
# sl12_nhu40_numobs8_bs16_lr5e-5
# sl32_nhu40_numobs8_bs16_lr5e-5
# sl6_nhu40_numobs8_bs16_lr5e-5
# [<src.Eval_MZA.Eval_MZA at 0x7f317470b880>,
#  <src.Eval_MZA.Eval_MZA at 0x7f30b8da1720>,
#  <src.Eval_MZA.Eval_MZA at 0x7f30b8da1d80>,
#  <src.Eval_MZA.Eval_MZA at 0x7f30b8da3b20>,
#  <src.Eval_MZA.Eval_MZA at 0x7f30b8da1cc0>,
#  <src.Eval_MZA.Eval_MZA at 0x7f30b8da3cd0>,
#  <src.Eval_MZA.Eval_MZA at 0x7f30b8dfca60>,
#  <src.Eval_MZA.Eval_MZA at 0x7f30b8dfd600>,
#  <src.Eval_MZA.Eval_MZA at 0x7f30b8dfdc30>]

# %%
#Sort Models
def param_find(model):
    return model.seq_len
models.sort(key = param_find)

for model in models:
    print(model.exp_name)

#plot learning curves
models[5].plot_learning_curves()
# Out:
# sl2_nhu40_numobs8_bs16_lr5e-5
# sl4_nhu40_numobs8_bs16_lr5e-5
# sl6_nhu40_numobs8_bs16_lr5e-5
# sl8_nhu40_numobs8_bs16_lr5e-5
# sl10_nhu40_numobs8_bs16_lr5e-5
# sl12_nhu40_numobs8_bs16_lr5e-5
# sl16_nhu40_numobs8_bs16_lr5e-5
# sl32_nhu40_numobs8_bs16_lr5e-5
# sl48_nhu40_numobs8_bs16_lr5e-5

# %%
epoch_num = 999
for i in range(len(models)):
    models[i].load_weights(epoch_num)

# %%
#One Step Prediction

models[0].load_and_preproc_data()
models[0].create_dataset(mode = "Train")
dataset = models[0].train_dataset
num_trajs = models[0].train_num_trajs
# eval_mza.train_size = 0.9
for i in range(1):#len(models)):
    
    # del eval_mza.lp_data 
    # torch.cuda.empty_cache()
    # del eval_mza.train_dataset
    # del eval_mza.train_dataloader
    
    x_nn_hat, Phi_nn_hat, Phi_nn, State_MSE, koop_out, seqmodel_out = models[i].predict_onestep(dataset, num_trajs)

    print(x_nn_hat.shape, Phi_nn_hat.shape, Phi_nn.shape)

    #Plotting one step prediction
    x_nn_hat.shape
# Out:
# Data Shape:  (1, 201, 51574)
# Not normalizing Input
# Train_Shape:  (1, 192, 51574)
# out of train
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 15
#       7 # eval_mza.train_size = 0.9
#       8 for i in range(1):#len(models)):
#       9
#      10     # del eval_mza.lp_data
#      11     # torch.cuda.empty_cache()
#      12     # del eval_mza.train_dataset
#      13     # del eval_mza.train_dataloader
# ---> 15     x_nn_hat, Phi_nn_hat, Phi_nn, State_MSE, koop_out, seqmodel_out = models[i].predict_onestep(dataset, num_trajs)
#      17     print(x_nn_hat.shape, Phi_nn_hat.shape, Phi_nn.shape)
#      19     #Plotting one step prediction
#
# File ~/Desktop/PhD_Projects/Mori-Zwanzig-Autoencoder/src/Eval_MZA.py:90, in Eval_MZA.predict_onestep(self, dataset, num_trajs)
#      86 Phi_seq_hat = Phi_seq_hat.reshape(adaptive_bs, self.seq_len, *sd) #[bs seqlen statedim]
#      87 # Phi_n_hat   = torch.squeeze(Phi_seq_hat[:, -1, :])
#      88
#      89 #Evolving in Time
# ---> 90 koop_out     = self.model.koopman(x_n)
#      91 if self.deactivate_seqmodel:
#      92     x_nn_hat     = koop_out
#
# File ~/anaconda3/envs/KS/lib/python3.10/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Desktop/PhD_Projects/Mori-Zwanzig-Autoencoder/src/Layers/Koopman.py:34, in Koopman.forward(self, x_n)
#      23 '''
#      24 Applies the learned koopman operator on the given observables.
#      25 Input
#    (...)
#      30     x_nn (torch.Tensor): [bs obsdim] predicted observables at the next time-step
#      31 '''
#      32 # assert g.size(-1) == self.kMatrix.size(0), 'Observables should have dim {}'.format(self.kMatrix.size(0))
#      33 # Build Koopman matrix (skew-symmetric with diagonal)
# ---> 34 kMatrix = self.kMatrix
#      35 # kMatrix = Variable(torch.Tensor(self.latent_size, self.latent_size)).to(self.device)
#      36 # utIdx = torch.triu_indices(self.latent_size, self.latent_size, offset=1)
#      37 # diagIdx = torch.stack([torch.arange(0,self.latent_size,dtype=torch.long).unsqueeze(0), \
#    (...)
#      40 # kMatrix[utIdx[1], utIdx[0]] = -self.kMatrixUT
#      41 # kMatrix[diagIdx[0], diagIdx[1]] = torch.nn.functional.relu(self.kMatrixDiag)
#      42 x_nn = torch.bmm(x_n.unsqueeze(1), kMatrix.expand(x_n.size(0), kMatrix.size(0), kMatrix.size(0)))
#
# File ~/anaconda3/envs/KS/lib/python3.10/site-packages/torch/nn/modules/module.py:1269, in Module.__getattr__(self, name)
#    1267     if name in modules:
#    1268         return modules[name]
# -> 1269 raise AttributeError("'{}' object has no attribute '{}'".format(
#    1270     type(self).__name__, name))
#
# AttributeError: 'Koopman' object has no attribute 'kMatrix'

# %%
#Load Data
with open('Data/2DCylinder/cyl_data_2.pkl', 'rb') as f:
    data_dict = pickle.load(f)

# %%
sub_X = data_dict["sub_X"]
sub_Y = data_dict["sub_Y"]
U_nn = Phi_nn_hat[...,:int(Phi_nn_hat.shape[-1]/2)].detach().cpu().numpy()
V_nn = Phi_nn_hat[...,int(Phi_nn_hat.shape[-1]/2):].detach().cpu().numpy()
U = Phi_nn[...,:int(Phi_nn.shape[-1]/2)].detach().cpu().numpy()
V = Phi_nn[...,int(Phi_nn.shape[-1]/2):].detach().cpu().numpy()

U_nn.shape, V_nn.shape, U.shape, V.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 sub_X = data_dict["sub_X"]
#       2 sub_Y = data_dict["sub_Y"]
# ----> 3 U_nn = Phi_nn_hat[...,:int(Phi_nn_hat.shape[-1]/2)].detach().cpu().numpy()
#       4 V_nn = Phi_nn_hat[...,int(Phi_nn_hat.shape[-1]/2):].detach().cpu().numpy()
#       5 U = Phi_nn[...,:int(Phi_nn.shape[-1]/2)].detach().cpu().numpy()
#
# NameError: name 'Phi_nn_hat' is not defined
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
def energy(u,v):
    k = 0.5*(np.mean(u**2,axis=-1) + np.mean(v**2,axis=-1))
    return k

k_pred = energy(U_nn,V_nn)
k = energy(U, V)

# %%
print(k.shape)
plt.plot(k[0,:], label = "DNS")
plt.plot(k_pred[0,:], label = "Predicted")
plt.legend()
# Out:
# (1, 192)

# %%
for i in range(100,150):
    plt.figure()
    plt.scatter(sub_X,sub_Y,c=U_nn[0,i], s=1, cmap = 'coolwarm')

# %%
for i in range (1):
    plt.figure()
    plt.plot(Phi_nn_hat.cpu().numpy()[i,:,0], label = "Predicted")
    plt.plot(Phi_nn.cpu().numpy()[i,:,0], label = "DNS")
    plt.legend()

plt.ylabel("u0")
plt.xlabel("Timesteps")
plt.figure()
plt.semilogy(State_MSE.cpu().numpy())
plt.xlabel("Timesteps")
plt.ylabel("MSE")
plt.legend()

# %%
for i in range (1):
    plt.figure()
    plt.plot(koop_out.cpu().numpy()[i,:,1], label = "Koopman Predicted")
    plt.plot(seqmodel_out.cpu().numpy()[i,:,1], label = "Seqmodel Predicted")
    plt.plot(Phi_nn_hat.cpu().numpy()[i,:,1], label = "DNS")
    plt.legend()

plt.figure()
plt.semilogy(State_MSE.cpu().numpy())
plt.xlabel("Timesteps")
plt.ylabel("MSE")
plt.legend()

# %%
#defining moving average
def moving_avg(u):

    pdu  = pd.DataFrame(u)
    u_ma = pdu.expanding().mean()
    return u_ma

# print(u_ma.shape)

# plt.plot(np.arange(u.shape[1]),u[...,0].squeeze(), label = "Mean Energy")
# plt.plot(u_ma)
# # plt.plot(np.arange(ref_X.shape[0]),ref_X_ma, linewidth = 3, label = "Time Moving Average")
# plt.xlabel("Time Units")
# plt.ylabel("Mean Energy")
# plt.legend()

# %%
Phi_nn_hat_ma = moving_avg(Phi_nn_hat.cpu().numpy())

plt.plot(Phi_nn_hat_ma)

# %%
#multistep prediction
timesteps = 150
initial_conditions = Phi_nn[:,0,:].to(models[0].device)

x_hat = torch.zeros((len(models),1,timesteps+1,models[0].num_obs))
Phi_hat = torch.zeros((len(models),1,timesteps+1,models[0].statedim)).to(models[0].device)

print("ic shape:", initial_conditions.shape)

for i in range(1,len(models)):
    x_hat[i], Phi_hat[i] = models[i].predict_multistep(initial_conditions, timesteps)

print(x_hat.shape, Phi_hat.shape)
# Out:
# ic shape: torch.Size([1, 51574])
# torch.Size([9, 1, 151, 8]) torch.Size([9, 1, 151, 51574])

# %%
# for i in range (1):
#     plt.figure()
#     plt.plot(Phi_nn.cpu().numpy()[i,:timesteps,0], '-', label = "Target")
#     plt.plot(Phi_hat.cpu().numpy()[i,:,0], '-', label = "Predicted")
#     plt.legend()

# %%
print(Phi_nn.shape, Phi_hat.shape)
State_MSE_multistep = torch.zeros((len(models),timesteps))

plt.figure()
for i in range(3,len(models)):
    State_MSE_multistep[i] = Eval_MZA.state_mse(Phi_nn[:,:timesteps],Phi_hat[i,:,:timesteps]).detach().cpu()
    plt.semilogy(State_MSE_multistep[i].numpy(), label = f"seq_len {models[i].seq_len}")

plt.legend()
plt.xlabel("Timesteps")
plt.ylabel("MSE")

# np.save("koopman_numobs32.npy",Phi_hat.cpu().numpy())
# Out:
# torch.Size([1, 192, 51574]) torch.Size([9, 1, 151, 51574])
# Text(0, 0.5, 'MSE')

# %%
import numpy
k1 = np.load("koopman_numobs4.npy")
k2 = np.load("koopman_numobs16.npy")
k3 = np.load("koopman_numobs32.npy")
k1.shape

plt.figure()
# plt.plot(k1[:,0])
plt.plot(np.linspace(0,101,1001),k2[0,:,1], label = "Koopman")
plt.plot(np.linspace(0,101,1001),Phi_nn[0,:1001,1].cpu().numpy(), label = "Target")
plt.plot(np.linspace(0,101,1001),Phi_hat.cpu().numpy()[0,:,1], label = "MZA Memory = 0.4 timeunits")
# plt.plot(k3[:,0])
plt.legend()
plt.xlabel("Timeunits")
plt.ylabel("u1")
k2.shape

# %%
mat = models[4].model.koopman.getKoopmanMatrix()
mat = mat.detach().cpu().numpy()
w, v = np.linalg.eig(mat)

idx = w.argsort()[::-1]
w = w[idx]
v = v[:,idx]

plt.figure()
plt.matshow(mat)
plt.colorbar()

plt.figure()
plt.plot(np.real(w), np.imag(w), ".")

# %%
print(w)
# Out:
# [9.7291493e-01+0.00000000e+00j 8.8811177e-01+0.00000000e+00j
#  5.0633091e-01+0.00000000e+00j 1.3349800e-01+0.00000000e+00j
#  2.2379347e-09+1.10174815e-05j 2.2379347e-09-1.10174815e-05j
#  9.6689845e-10+4.39437690e-06j 9.6689845e-10-4.39437690e-06j]

# %%
plt.contourf(abs(v))
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
